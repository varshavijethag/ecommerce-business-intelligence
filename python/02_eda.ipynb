# %%
import pandas as pd

monthly_sales = pd.read_csv("../data/cleaned/monthly_sales.csv")

monthly_sales.head()
# Out:
#   order_month      sales
# 0     2016-09     267.36
# 1     2016-10   49507.66
# 2     2016-12      10.90
# 3     2017-01  120312.87
# 4     2017-02  247303.02

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.plot(
    monthly_sales["order_month"],
    monthly_sales["sales"],
    marker="o"
)

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
yearly_sales = pd.read_csv("../data/cleaned/yearly_sales.csv")

yearly_sales
# Out:
#    year       sales
# 0  2016    49785.92
# 1  2017  6155806.98
# 2  2018  7386050.80

# %%
plt.figure(figsize=(8, 5))

plt.bar(
    yearly_sales["year"].astype(str),
    yearly_sales["sales"]
)

plt.title("Yearly Sales")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.tight_layout()

plt.show()

# %%
category_sales = pd.read_csv("../data/cleaned/category_sales.csv")

category_sales.head(10)
# Out:
#                  category       sales
# 0            beleza_saude  1258681.34
# 1      relogios_presentes  1205005.68
# 2         cama_mesa_banho  1036988.68
# 3           esporte_lazer   988048.97
# 4  informatica_acessorios   911954.32
# 5        moveis_decoracao   729762.49
# 6              cool_stuff   635290.85
# 7   utilidades_domesticas   632248.66
# 8              automotivo   592720.11
# 9      ferramentas_jardim   485256.46

# %%
top_categories = category_sales.head(10).sort_values("sales")

plt.figure(figsize=(10, 6))

plt.barh(
    top_categories["category"],
    top_categories["sales"]
)

plt.title("Top 10 Product Categories by Sales")
plt.xlabel("Sales")
plt.ylabel("Category")
plt.tight_layout()

plt.show()

# %%
payment_summary = pd.read_csv("../data/cleaned/payment_summary.csv")

payment_summary
# Out:
#   payment_type  payment_count
# 0  credit_card          76795
# 1       boleto          19784
# 2      voucher           5775
# 3   debit_card           1529
# 4  not_defined              3

# %%
plt.figure(figsize=(8, 5))

plt.bar(
    payment_summary["payment_type"],
    payment_summary["payment_count"]
)

plt.title("Orders by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Payments")
plt.xticks(rotation=20)
plt.tight_layout()

plt.show()

# %%
top_cities = pd.read_csv("../data/cleaned/top_customer_cities.csv")

top_cities
# Out:
#                     city  customer_count
# 0              sao paulo           15540
# 1         rio de janeiro            6882
# 2         belo horizonte            2773
# 3               brasilia            2131
# 4               curitiba            1521
# 5               campinas            1444
# 6           porto alegre            1379
# 7               salvador            1245
# 8              guarulhos            1189
# 9  sao bernardo do campo             938

# %%
top_cities_plot = top_cities.sort_values("customer_count")

plt.figure(figsize=(10, 6))

plt.barh(
    top_cities_plot["city"],
    top_cities_plot["customer_count"]
)

plt.title("Top 10 Customer Cities")
plt.xlabel("Number of Customers")
plt.ylabel("City")
plt.tight_layout()

plt.show()

# %%
top_states = pd.read_csv("../data/cleaned/top_customer_states.csv")

top_states
# Out:
#   state  customer_count
# 0    SP           41746
# 1    RJ           12852
# 2    MG           11635
# 3    RS            5466
# 4    PR            5045
# 5    SC            3637
# 6    BA            3380
# 7    DF            2140
# 8    ES            2033
# 9    GO            2020

# %%
top_states_plot = top_states.sort_values("customer_count")

plt.figure(figsize=(9, 6))

plt.barh(
    top_states_plot["state"],
    top_states_plot["customer_count"]
)

plt.title("Top 10 Customer States")
plt.xlabel("Number of Customers")
plt.ylabel("State")
plt.tight_layout()

plt.show()

# %%
review_scores = pd.read_csv("../data/cleaned/review_score_summary.csv")

review_scores
# Out:
#    review_score  review_count
# 0             1         11424
# 1             2          3151
# 2             3          8179
# 3             4         19142
# 4             5         57328

# %%
plt.figure(figsize=(8, 5))

plt.bar(
    review_scores["review_score"].astype(str),
    review_scores["review_count"]
)

plt.title("Customer Review Score Distribution")
plt.xlabel("Review Score")
plt.ylabel("Number of Reviews")
plt.tight_layout()

plt.show()

# %%
delivery_data = pd.read_csv("../data/cleaned/delivery_analysis.csv")

delivery_data["delivery_status"].value_counts()
# Out:
# delivery_status
# On Time    88649
# Late       10792
# Name: count, dtype: int64

# %%
delivery_status = delivery_data["delivery_status"].value_counts()

plt.figure(figsize=(7, 5))

plt.bar(
    delivery_status.index,
    delivery_status.values
)

plt.title("Delivery Status")
plt.xlabel("Delivery Status")
plt.ylabel("Number of Orders")
plt.tight_layout()

plt.show()

# %%
delivery_kpi = pd.read_csv("../data/cleaned/delivery_kpi.csv")

delivery_kpi
# Out:
#                   metric  value
# 0  average_delivery_days  12.09
# 1  on_time_delivery_rate  89.15

# %%
review_kpi = pd.read_csv("../data/cleaned/review_kpi.csv")

review_kpi
# Out:
#                  metric  value
# 0  average_review_score   4.09

# %%
order_status = pd.read_csv("../data/cleaned/order_status_summary.csv")

order_status
# Out:
#   order_status  order_count
# 0    delivered        96478
# 1      shipped         1107
# 2     canceled          625
# 3  unavailable          609
# 4     invoiced          314
# 5   processing          301
# 6      created            5
# 7     approved            2

# %%
order_status = pd.read_csv("../data/cleaned/order_status_summary.csv")

order_status
# Out:
#   order_status  order_count
# 0    delivered        96478
# 1      shipped         1107
# 2     canceled          625
# 3  unavailable          609
# 4     invoiced          314
# 5   processing          301
# 6      created            5
# 7     approved            2

# %%
plt.figure(figsize=(9, 5))

plt.bar(
    order_status["order_status"],
    order_status["order_count"]
)

plt.title("Order Status Distribution")
plt.xlabel("Order Status")
plt.ylabel("Number of Orders")
plt.xticks(rotation=25)
plt.tight_layout()

plt.show()
